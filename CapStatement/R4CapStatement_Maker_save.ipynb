# %% [markdown]
# ## Create FHIR R4 CapStatement Resource
#
# ### Outline:
#
# - Source excel with requirements
# - pandas to convert in python Ordered Dict
# - build json
# - generate narrative using Jinja2 templates
#
# ### Prerequisites:
#
# - Python 3.6 or greater

# %% [markdown]
# ### Import FHIRClient and other libraries

# %%
# %config IPCompleter.greedy=True

# %%
from fhirclient.r4models.fhirabstractbase import FHIRValidationError
from fhirclient.r4models import searchparameter as SP
from fhirclient.r4models import capabilitystatement as CS
from fhirclient.r4models import bundle as B
from fhirclient.r4models import narrative as N
import fhirclient.models.identifier as I
import fhirclient.r4models.identifier as I
import fhirclient.r4models.coding as C
import fhirclient.r4models.codeableconcept as CC
import fhirclient.r4models.fhirdate as D
import fhirclient.r4models.extension as X
import fhirclient.r4models.contactdetail as CD
import fhirclient.r4models.fhirreference as FR
from json import dumps, loads, load
from requests import get, post, put
import os
from pathlib import Path
from csv import reader as csvreader
from IPython.display import display as Display, HTML, Markdown
from pprint import pprint
from collections import namedtuple
from pandas import *
from datetime import datetime, date
from jinja2 import Environment, FileSystemLoader, select_autoescape
from stringcase import snakecase, titlecase
from itertools import zip_longest
from openpyxl import load_workbook
from commonmark import commonmark
from lxml import etree

# %% [markdown]
# ####  Assign Global Variables
#
#
# Here is where we assign all the global variables for this example such as the canonical base and project information

# %% [markdown]
# #### Conformance Extension

# %%
def get_conf(conf='MAY',as_dict=False):
    if as_dict:
        return [X.Extension(dict(
            url = conf_url,
            valueCode = conf
            )).as_json()]
    else:
        return [X.Extension(dict(
            url = conf_url,
            valueCode = conf
            ))]

# %% [markdown]
# ### validate

# %%
# *********************** validate Resource ********************************

def validate(r):

    fhir_test_server = 'http://test.fhir.org/r4'

    headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }

    # profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
 
    params = dict(
      # profile = 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient' # The official URL for this profile is: http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient
        )
    
    #   r = requests.post('https://httpbin.org/post', data = {'key':'value'})
    r = post(f'{fhir_test_server}/Questionnaire/$validate', params = params, headers = headers, data = dumps(r.as_json()))
    # return r.status_code
    # view  output
    # return (r.json()["text"]["div"])
    return r

# %% [markdown]
# #### first the meta sheet

# %%
print (in_path)
print (in_file)

xls = ExcelFile(f'{in_path}{in_file}')
df = read_excel(xls,'meta',na_filter = False)

df
# Out:
# R4capabilitystatement-server.j2
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-66-c919aa6ae854> in <module>
#       2 print (in_file)
#       3
# ----> 4 xls = ExcelFile(f'{in_path}{in_file}')
#       5 df = read_excel(xls,'meta',na_filter = False)
#       6
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     155         formatting_info=formatting_info,
#     156         on_demand=on_demand,
# --> 157         ragged_rows=ragged_rows,
#     158     )
#     159     return bk
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      90         t1 = perf_counter()
#      91         bk.load_time_stage_1 = t1 - t0
# ---> 92         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      93         if not biff_version:
#      94             raise XLRDError("Can't determine file's BIFF version")
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/book.py in getbof(self, rqd_stream)
#    1276             bof_error('Expected BOF record; met end of file')
#    1277         if opcode not in bofcodes:
# -> 1278             bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1279         length = self.get2bytes()
#    1280         if length == MY_EOF:
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/book.py in bof_error(msg)
#    1270
#    1271         def bof_error(msg):
# -> 1272             raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#    1273         savpos = self._position
#    1274         opcode = self.get2bytes()
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'<?xml ve'

# %% [markdown]
# ### Get Cap Statement input data

# %% [markdown]
# #### Create NamedTuple from df to use dot notation

# %%
d = dict(zip(df.Element, df.Value))
meta = namedtuple("Meta", d.keys())(*d.values())      
         
meta.id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-d2f38fe75b4f> in <module>
# ----> 1 d = dict(zip(df.Element, df.Value))
#       2 meta = namedtuple("Meta", d.keys())(*d.values())
#       3
#       4 meta.id
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Element'

# %% [markdown]
# ### Create CS instance

# %%
def get_sys_op():
    op_list = []
    df_op = read_excel(xls,'ops',na_filter = False)
    for i in df_op.itertuples(index=True):
        if i.type == 'system':
            op = CS.CapabilityStatementRestResourceOperation()
            op.name = i.name 
            op.definition = i.definition
            op.extension = get_conf(i.conf) 
            op_list.append(op.as_json())
    return op_list


def get_rest_ints():
    ri_list = []
    df_ri = read_excel(xls,'rest_interactions',na_filter = False)
    for i in df_ri.itertuples(index=True):
        ri = CS.CapabilityStatementRestInteraction()
        ri.code = i.code 
        ri.documentation = i.doc if i.doc not in none_list else None
        ri.extension = get_conf(i.conf)
        print(ri.as_json())
        ri_list.append(ri.as_json())
    return ri_list

def get_igs():
    ig_list = []
    df_igs = read_excel(xls,'igs',na_filter = False)
    for ig in df_igs.itertuples(index=True):
        ig_list.append(ig.uri)
    return ig_list # TODO add conformance to this

def kebab_to_pascal(word):
    return ''.join(x.capitalize() for x in word.split('-'))

cs = CS.CapabilityStatement()
cs.id = meta.id
cs.url = f'{canon}CapabilityStatement/{meta.id}'
cs.version = meta.version
cs.name = f'{kebab_to_pascal(meta.id)}{cs.resource_type}'
cs.title = f'{titlecase(meta.id).replace("Us ", "US ")} {cs.resource_type}'
cs.status = 'active'

cs.experimental = False
cs.date = f_now  # as FHIRDate
cs.publisher = publisher
cs.contact = [CD.ContactDetail( {"telecom" : [ publisher_endpoint ] })]
cs.description = meta.description
cs.jurisdiction = [f_jurisdiction]
cs.kind = 'requirements'
cs.fhirVersion = meta.fhirVersion
cs.acceptUnknown = 'both'
cs.format = [
    "xml",
    "json"
  ]
cs.patchFormat = [
    "application/json-patch+json",
  ]
cs.implementationGuide = meta.ig.split(",") + get_igs()
rest = CS.CapabilityStatementRest(dict(
    mode = meta.mode,
    documentation = meta.documentation,
    security = dict(
        description = meta.security
        ) if meta.security else None,
    interaction = get_rest_ints(),
    operation = get_sys_op()
    ))
cs.rest = [rest]


cs.as_json()
# Out:
# {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation', 'valueCode': 'MAY'}], 'code': 'transaction'}
# {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation', 'valueCode': 'MAY'}], 'code': 'batch'}
# {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation', 'valueCode': 'MAY'}], 'code': 'search-system'}
# {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation', 'valueCode': 'MAY'}], 'code': 'history-system'}
# {'id': 'davinci-pdex-plan-net',
#  'contact': [{'telecom': [{'system': 'url',
#      'value': 'http://www.hl7.org/Special/committees/inm/index.cfm'}]}],
#  'date': '2020-06-09',
#  'description': 'This Section describes the expected capabilities of the Plan-Net Server actor which is responsible for providing responses to the queries submitted by the Plan-Net Requestors. The complete list of FHIR profiles, RESTful operations, and search parameters supported by Plan-Net Servers are defined. Systems implementing this capability statement should meet the <CMS FInal Rule requirement for provider directory access>.  Plan-Net  Clients have the option of choosing from this list to access necessary data based on their local use cases and other contextual requirements.',
#  'experimental': False,
#  'fhirVersion': '4.0.0',
#  'format': ['xml', 'json'],
#  'implementationGuide': ['http://hl7.org/fhir/us/davinci-pdex-plan-net'],
#  'jurisdiction': [{'coding': [{'code': 'US',
#      'system': 'urn:iso:std:iso:3166'}]}],
#  'kind': 'requirements',
#  'name': 'DavinciPdexPlanNetCapabilityStatement',
#  'patchFormat': ['application/json-patch+json'],
#  'publisher': 'HL7 International - Infrastructure and Messaging Work Group',
#  'rest': [{'documentation': 'The Plan-Net  Server **SHALL**:\n\n1. Support all profiles defined in this Implementation Guide..\n1.  Implement the RESTful behavior according to the FHIR specification.\n1. Return the following response classes:\n   - (Status 400): invalid parameter\n   - (Status 401/4xx): unauthorized request\n   - (Status 403): insufficient scope\n   - (Status 404): unknown resource\n   - (Status 410): deleted resource.\n1. Support json source formats for all Plan-Net interactions.\n\nThe Plan-Net  Server **SHOULD**:\n\n1. Support xml source formats for all Plan-Net  interactions.\n1. Identify the Plan-Net  profiles supported as part of the FHIR `meta.profile` attribute for each instance.',
#    'interaction': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation',
#        'valueCode': 'MAY'}],
#      'code': 'transaction'},
#     {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation',
#        'valueCode': 'MAY'}],
#      'code': 'batch'},
#     {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation',
#        'valueCode': 'MAY'}],
#      'code': 'search-system'},
#     {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation',
#        'valueCode': 'MAY'}],
#      'code': 'history-system'}],
#    'mode': 'server',
#    'security': {'description': '1. See the [General Security Considerations](security.html) section for requirements and recommendations.\n1. A server **SHALL** reject any unauthorized requests by returning an `HTTP 401` unauthorized response code.'}}],
#  'status': 'active',
#  'title': 'Davinci Pdex Plan Net CapabilityStatement',
#  'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CapabilityStatement/davinci-pdex-plan-net',
#  'version': '1.0.0',
#  'resourceType': 'CapabilityStatement'}

# %% [markdown]
# #### Then the list of IG profiles

# %%
xls = ExcelFile(f'{in_path}{in_file}')
df = read_excel(xls,'profiles',na_filter = False)

df
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-54-f1f2606c18de> in <module>
# ----> 1 xls = ExcelFile(f'{in_path}{in_file}')
#       2 df = read_excel(xls,'profiles',na_filter = False)
#       3
#       4 df
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     155         formatting_info=formatting_info,
#     156         on_demand=on_demand,
# --> 157         ragged_rows=ragged_rows,
#     158     )
#     159     return bk
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      90         t1 = perf_counter()
#      91         bk.load_time_stage_1 = t1 - t0
# ---> 92         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      93         if not biff_version:
#      94             raise XLRDError("Can't determine file's BIFF version")
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/book.py in getbof(self, rqd_stream)
#    1276             bof_error('Expected BOF record; met end of file')
#    1277         if opcode not in bofcodes:
# -> 1278             bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1279         length = self.get2bytes()
#    1280         if length == MY_EOF:
#
# ~/Library/Python/3.7/lib/python/site-packages/xlrd/book.py in bof_error(msg)
#    1270
#    1271         def bof_error(msg):
# -> 1272             raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#    1273         savpos = self._position
#    1274         opcode = self.get2bytes()
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'<?xml ve'

# %% [markdown]
# #### add Resources
#
# - read sheets for resource attributes, interaction attributes,  search attributes, profiles, and combo search parameters

# %% [markdown]
# ### Convert model to dict and add extensions to primitives **Deactivated ( marked a raw block ) since will need to use dict in subsuquent steps.

# %% [raw]
# #add in conformance expectations for primitives
# #convert to dict since model can't handle primitive extensions
#
# resttype_dict = res.as_json()
#
# for i in ['Include','RevInclude']:
#     element = f'_search{i}'
#
#     resttype_dict[element] = []
#     print(element)
#     for expectation in ['should', 'shall']: # list all should includes first
#         sp_attr = f'{expectation}_{i.lower()}'
#         print(sp_attr)
#         includes = getattr(r,sp_attr).split(',')
#         print(includes)
#
#         for include in includes:
#             if include not in none_list:
#                 print(include)
#                 conf = get_conf(expectation.upper(),as_dict=True)
#                 print(conf)
#                 conf = conf
#                 print(conf)
#                 resttype_dict[element].append(conf)
#
#     if not resttype_dict[element]:
#             del(resttype_dict[element])
#
# print(resttype_dict)
#
# print(dumps(cs.as_json(),indent=3))

# %% [markdown]
# ### Validate

# %%
df_resources = read_excel(xls,'resources',na_filter = False)
df_profiles = read_excel(xls,'profiles',na_filter = False)
df_i = read_excel(xls,'interactions',na_filter = False)
df_sp = read_excel(xls,'sps',na_filter = False)
df_combos = read_excel(xls,'sp_combos',na_filter = False)
df_op = read_excel(xls,'ops',na_filter = False)


def get_i(type):
    int_list = []
    print("get_i - " + type)
    for i in df_i.itertuples(index=True):
        
        print(i.code, getattr(i,f'conf_{type}'))
        if getattr(i,f'conf_{type}') not in none_list:
            int  = CS.CapabilityStatementRestResourceInteraction()
            int.code = i.code
            try:
                int.documentation = getattr(i,f'doc_{type}') if getattr(i,f'doc_{type}') not in none_list else None
            except AttributeError:
                pass
            int.extension = get_conf(getattr(i,f'conf_{type}'))    
            int_list.append(int.as_json())
        
    return int_list


def get_sp(r_type):
    sp_list = []
    for i in df_sp.itertuples(index=True):
        if i.base == r_type:
            sp  = CS.CapabilityStatementRestResourceSearchParam()
            sp.name = i.code
            
            # TODO need to fix this to reference the package file to reconcile definition to names
            if i.code in sp_specials: #special case temp fix for us-core
                sp.definition = sp_specials[i.code]
            elif i.update == 'Y' or i.exists =='N':
                sp.definition = (f'{canon}SearchParameter/{pre.lower()}-{i.base.lower()}-{i.code.split("_")[-1]}')                  
            else:  # use base definition
                sp.definition = f'{fhir_base_url}SearchParameter/{i.base}-{i.code.split("_")[-1]}'  # removes the '_' for things like _id
                                 
            print(sp.definition)
                                 
            sp.type = i.type
            sp.extension = get_conf(i.base_conf)
            print(sp.as_json())                
            sp_list.append(sp.as_json())
                             
    return sp_list


def get_combo_ext(r_type,combos):
    x_list = []
    for combo in combos:
        # convert to extension
        combo_ext = X.Extension()
        combo_ext.url = combo_url
        combo_conf_ext = get_conf(combo[1])
        combo_ext.extension=combo_conf_ext
        for param in combo[0].split(','):
            req_combo = X.Extension(
                dict (
                    url = 'required',
                    valueString = param   #http://hl7.org/fhir/us/core/SearchParameter/us-core-patient-family
                    )
                )
            combo_ext.extension.append(req_combo)
        x_list.append(combo_ext)
        # print(x_list)
    return x_list
                             
def get_op(r_type):
    op_list = []
    for i in df_op.itertuples(index=True):
         if i.type == r_type:
            op = CS.CapabilityStatementRestResourceOperation()
            op.name = i.name 
            op.definition = i.definition
            op.documentation = i.documentation if i.documentation not in none_list else None
            op.extension = get_conf(i.conf) 
            op_list.append(op.as_json())
                           
    return op_list 

rest.resource =  []
for r in df_resources.itertuples(index=True):
    if not r.type.startswith('!'):
         print(r.type, r.conformance, r.readHistory)
        supported_profile = [p.Profile for p in df_profiles.itertuples(index=True) if p.Type == r.type]
        pprint(supported_profile)                         
        res = CS.CapabilityStatementRestResource(
        dict(
            type = r.type,
            documentation = r.documentation if r.documentation not in none_list else None,
            versioning = r.versioning if r.versioning not in none_list else None,
            readHistory = r.readHistory if r.readHistory not in none_list else None,
            updateCreate = r.updateCreate if r.updateCreate not in none_list else None,
            conditionalCreate = r.conditionalCreate if r.conditionalCreate not in none_list else None,
            conditionalRead = r.conditionalRead if r.conditionalRead not in none_list else None,
            conditionalUpdate = r.conditionalUpdate if r.conditionalUpdate not in none_list else None,
            conditionalDelete = r.conditionalDelete if r.conditionalDelete not in none_list else None,
            referencePolicy = [x for x in r.referencePolicy.split(",") if x],
            searchInclude =  [x for x in r.shall_include.split(",") + r.should_include.split(",") if x],
            searchRevInclude =  [x for x in r.shall_revinclude.split(",") + r.should_revinclude.split(",") if x],
            interaction = get_i(r.type),
            searchParam = get_sp(r.type),
            operation = get_op(r.type),
            #profile = f'{fhir_base_url}StructureDefinition/{r.type}',
            supportedProfile = supported_profile,
            )
        )
        res.extension = get_conf(r.conformance)
        combos = {(i.combo,i.combo_conf) for i in df_combos.itertuples(index=True) if i.base == r.type}
        res.extension = res.extension + get_combo_ext(r.type,combos) # convert list to  lst of combo extension
                            
                                 
        '''
        #TODO add in conformance expectations for primitives 
        #need to convert to dict since model can't handle primitive extensions

        resttype_dict = res.as_json()

        for i in ['Include','RevInclude']:
            element = f'_search{i}'

            resttype_dict[element] = []
            print(element)
            for expectation in ['should', 'shall']: # list all should includes first
                sp_attr = f'{expectation}_{i.lower()}'
                print(sp_attr) 
                includes = getattr(r,sp_attr).split(',')
                print(includes)

                for include in includes:
                    if include not in none_list:             
                        print(include)
                        conf = get_conf(expectation.upper(),as_dict=True)
                        print(conf)
                        conf = conf
                        print(conf)        
                        resttype_dict[element].append(conf)

            if not resttype_dict[element]:
                    del(resttype_dict[element])

        print(dumps(resttype_dict, indent = 4))
        res = CS.CapabilityStatementRestResource(resttype_dict, strict = False)
        print('++++++++++++++++RES.__dict__+++++++++++++++++++')
        print(dumps(res._searchRevInclude, indent = 4))
        '''                               
                                 
        rest.resource.append(res)

rest.resource =  sorted(rest.resource,key = lambda x: x.type)  # sort resources                         
cs.rest = [rest]
    
print(dumps(cs.as_json(),indent=3))
# Out:
#   File "<tokenize>", line 90
#     supported_profile = [p.Profile for p in df_profiles.itertuples(index=True) if p.Type == r.type]
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
 #validate and write to file

print('...validating')
r = validate(cs)
display(HTML(f'<h1>Validation output</h1><h3>Status Code = {r.status_code}</h3> {r.json()["text"]["div"]}'))
# Out:
# ...validating
# <h1>Validation output</h1><h3>Status Code = 500</h3> <div xmlns="http://www.w3.org/1999/xhtml"><p>No Database Connections Available for "Operation" (used: InUse 100 of 100: Operation 5 days (Select Ids.ResourceKey, Types.ResourceName, Ids.Id, VersionId, Secure, StatedDate, Name, Versions.Status, Score1, Score2, Tags, JsonContent from Versions, Ids, Sessions, SearchEntries, Types where Ids.Deleted = 0 and SearchEntries.ResourceVersionKey = Versions.ResourceVersionKey and Types.ResourceTypeKey = Ids.ResourceTypeKey and Versions.SessionKey = Sessions.SessionKey and SearchEntries.ResourceKey = Ids.ResourceKey and SearchEntries.SearchKey = 24235 order by SortValue ASC)
# fhir.sweep 5 days (insert into Versions (ResourceVersionKey, ResourceKey, StatedDate, TransactionDate, VersionId, Format, Status, SessionKey, ForTesting, Secure, Tags, XmlContent, XmlSummary, JsonContent, JsonSummary) values (:k, :rk, :sd, :td, :v, :f, 0, :s, :ft, :sec, :tb, :xc, :xs, :jc, :js))
# Indexing Lookup 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (Insert into SearchEntries Select 24236, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (Insert into SearchEntries Select 24237, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (Insert into SearchEntries Select 24238, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (Insert into SearchEntries Select 24239, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Provenance')
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Provenance')
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Patient')
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Provenance')
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supp

# %% [markdown]
# ### Create Narrative
#
# - Using Jinja2 Template create xhtml for narrative

# %% [markdown]
# #### First: Get spec_internal from package.tgz a json file which includes canonical to local relative page links
#
# Note for this to work you have to have a working build that already contains all the needed artifacts.

# %%
#******************** Need to update when changing IGs *************************************************
fhir_base_url = 'http://hl7.org/fhir/'
#pre = "US-Core"
pre = "Davinci"
#canon = "http://hl7.org/fhir/us/core/"  # don't forget the slash  - fix using os.join or path
canon = "http://hl7.org/fhir/us/davinci-pdex-plan-net/"  # don't forget the slash  - fix using os.join or path
#canon = "http://hl7.org/fhir/us/davinci-deqm/"  # don't forget the slash  - fix using os.join or path
#ig_folder = 'US-Core'
#publisher = 'HL7 International - US Realm Steering Committee'
publisher = 'HL7 International - Infrastructure and Messaging Work Group'
'''
publisher_endpoint = dict(
                        system = 'url',
                        value = 'http://www.hl7.org/Special/committees/usrealm/index.cfm'
                        )
'''
'''publisher_endpoint = dict(
                        system = 'url',
                        value = 'http://www.hl7.org/Special/committees/cds/index.cfm'
                        )
'''
publisher_endpoint = dict(
                        system = 'url',
                        value = 'http://www.hl7.org/Special/committees/inm/index.cfm'
                        )


ig_package_tar_path =  "/Users/skravitz/git/davinci-pdex-plan-net/fsh/build/output/"
ig_package_path =       "/Users/skravitz/git/davinci-pdex-plan-net/fsh/build/output/"
ig_source_path =    "/Users/skravitz/git/davinci-pdex-plan-net/fsh/build/input"
in_path = "/Users/skravitz/git/MyNotebooks/CapStatement/temp_source_spreadsheets/"
in_file ="plan-net-server.xlsx"

#******************** Need to update when changing IGs *************************************************

f_jurisdiction =  CC.CodeableConcept({
      "coding" : [
        {
          "system" : "urn:iso:std:iso:3166",
          "code" : "US"
        }
      ]
    })

conf_url = 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-expectation'
combo_url = 'http://hl7.org/fhir/StructureDefinition/capabilitystatement-search-parameter-combination'

sp_specials = {'us-core-includeprovenance':'http://hl7.org/fhir/us/core/SearchParameter/us-core-includeprovenance'}  # dict to for SP to get right canonicals, may use spreadsheet or package file in future.

none_list = ['', ' ', 'none', 'n/a', 'N/A', 'N', 'False']

sep_list = (',', ';', ' ', ', ', '; ')

f_now = D.FHIRDate(str(date.today()))
f_now.as_json()
# Out:
# '2020-06-09'

# %%
import tarfile
def get_si(path):
    print (path)
    with tarfile.open(f'{path}/package.tgz', mode='r') as tf:
        #pprint(tf.getnames())
        f = tf.extractfile('other/spec.internals')
        r = f.read()
        return(loads(r))

def get_si2(path):
    with open(f'{path}/package/other/spec.internals', 'r', encoding='utf-8-sig') as f:
        r = f.read()
        return(loads(r, encoding = 'utf-8'))

'''
try:      
    si = get_si(ig_package_tar_path)
except FileNotFoundError:
    
'''  
si = get_si2(ig_package_path) # get from package (json) file in local .fhir directory
path_map = si['paths']
path_map
# Out:
# {'http://hl7.org/fhir/us/davinci-pdex-plan-net/ImplementationGuide/hl7.fhir.us.davinci-pdex-plan-net|0.1.0': '0.1.0/ImplementationGuide-hl7.fhir.us.davinci-pdex-plan-net.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ImplementationGuide/hl7.fhir.us.davinci-pdex-plan-net': 'ImplementationGuide-hl7.fhir.us.davinci-pdex-plan-net.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Endpoint|0.1.0': '0.1.0/StructureDefinition-plannet-Endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Endpoint': 'StructureDefinition-plannet-Endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-HealthcareService|0.1.0': '0.1.0/StructureDefinition-plannet-HealthcareService.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-HealthcareService': 'StructureDefinition-plannet-HealthcareService.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-InsurancePlan|0.1.0': '0.1.0/StructureDefinition-plannet-InsurancePlan.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-InsurancePlan': 'StructureDefinition-plannet-InsurancePlan.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location|0.1.0': '0.1.0/StructureDefinition-plannet-Location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location': 'StructureDefinition-plannet-Location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Network|0.1.0': '0.1.0/StructureDefinition-plannet-Network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Network': 'StructureDefinition-plannet-Network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Organization|0.1.0': '0.1.0/StructureDefinition-plannet-Organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Organization': 'StructureDefinition-plannet-Organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-OrganizationAffiliation|0.1.0': '0.1.0/StructureDefinition-plannet-OrganizationAffiliation.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-OrganizationAffiliation': 'StructureDefinition-plannet-OrganizationAffiliation.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Practitioner|0.1.0': '0.1.0/StructureDefinition-plannet-Practitioner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Practitioner': 'StructureDefinition-plannet-Practitioner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-PractitionerRole|0.1.0': '0.1.0/StructureDefinition-plannet-PractitionerRole.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-PractitionerRole': 'StructureDefinition-plannet-PractitionerRole.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility|0.1.0': '0.1.0/StructureDefinition-accessibility.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility': 'StructureDefinition-accessibility.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/communication-proficiency|0.1.0': '0.1.0/StructureDefinition-communication-proficiency.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/communication-proficiency': 'StructureDefinition-communication-proficiency.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/contactpoint-availabletime|0.1.0': '0.1.0/StructureDefinition-contactpoint-availabletime.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/contactpoint-availabletime': 'StructureDefinition-contactpoint-availabletime.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/endpoint-usecase|0.1.0': '0.1.0/StructureDefinition-endpoint-usecase.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/endpoint-usecase': 'StructureDefinition-endpoint-usecase.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/location-reference|0.1.0': '0.1.0/StructureDefinition-location-reference.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/location-reference': 'StructureDefinition-location-reference.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/network-reference|0.1.0': '0.1.0/StructureDefinition-network-reference.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/network-reference': 'StructureDefinition-network-reference.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/newpatientprofile|0.1.0': '0.1.0/StructureDefinition-newpatientprofile.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/newpatientprofile': 'StructureDefinition-newpatientprofile.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/newpatients|0.1.0': '0.1.0/StructureDefinition-newpatients.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/newpatients': 'StructureDefinition-newpatients.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/org-description|0.1.0': '0.1.0/StructureDefinition-org-description.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/org-description': 'StructureDefinition-org-description.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/practitioner-qualification|0.1.0': '0.1.0/StructureDefinition-practitioner-qualification.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/practitioner-qualification': 'StructureDefinition-practitioner-qualification.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/qualification|0.1.0': '0.1.0/StructureDefinition-qualification.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/qualification': 'StructureDefinition-qualification.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/via-intermediary|0.1.0': '0.1.0/StructureDefinition-via-intermediary.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/via-intermediary': 'StructureDefinition-via-intermediary.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/AccessibilityVS|0.1.0': '0.1.0/ValueSet-AccessibilityVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/AccessibilityVS': 'ValueSet-AccessibilityVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/EndpointConnectionTypeVS|0.1.0': '0.1.0/ValueSet-EndpointConnectionTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/EndpointConnectionTypeVS': 'ValueSet-EndpointConnectionTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/EndpointPayloadTypeVS|0.1.0': '0.1.0/ValueSet-EndpointPayloadTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/EndpointPayloadTypeVS': 'ValueSet-EndpointPayloadTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/EndpointUsecaseVS|0.1.0': '0.1.0/ValueSet-EndpointUsecaseVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/EndpointUsecaseVS': 'ValueSet-EndpointUsecaseVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/HealthcareServiceCategoryVS|0.1.0': '0.1.0/ValueSet-HealthcareServiceCategoryVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/HealthcareServiceCategoryVS': 'ValueSet-HealthcareServiceCategoryVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/IndividualAndGroupSpecialtiesVS|0.1.0': '0.1.0/ValueSet-IndividualAndGroupSpecialtiesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/IndividualAndGroupSpecialtiesVS': 'ValueSet-IndividualAndGroupSpecialtiesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/IndividualPractitionerRolesVS|0.1.0': '0.1.0/ValueSet-IndividualPractitionerRolesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/IndividualPractitionerRolesVS': 'ValueSet-IndividualPractitionerRolesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/IndividualSpecialtyAndDegreeLicenseCertificateVS|0.1.0': '0.1.0/ValueSet-IndividualSpecialtyAndDegreeLicenseCertificateVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/IndividualSpecialtyAndDegreeLicenseCertificateVS': 'ValueSet-IndividualSpecialtyAndDegreeLicenseCertificateVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/InsurancePlanTypeVS|0.1.0': '0.1.0/ValueSet-InsurancePlanTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/InsurancePlanTypeVS': 'ValueSet-InsurancePlanTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/InsuranceProductTypeVS|0.1.0': '0.1.0/ValueSet-InsuranceProductTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/InsuranceProductTypeVS': 'ValueSet-InsuranceProductTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/LanguageProficiencyVS|0.1.0': '0.1.0/ValueSet-LanguageProficiencyVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/LanguageProficiencyVS': 'ValueSet-LanguageProficiencyVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/MinEndpointConnectionTypeVS|0.1.0': '0.1.0/ValueSet-MinEndpointConnectionTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/MinEndpointConnectionTypeVS': 'ValueSet-MinEndpointConnectionTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/NonIndividualPractitionerRolesVS|0.1.0': '0.1.0/ValueSet-NonIndividualPractitionerRolesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/NonIndividualPractitionerRolesVS': 'ValueSet-NonIndividualPractitionerRolesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/NonIndividualSpecialtiesVS|0.1.0': '0.1.0/ValueSet-NonIndividualSpecialtiesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/NonIndividualSpecialtiesVS': 'ValueSet-NonIndividualSpecialtiesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/NonIndividualSpecialtyAndDegreeLicenseCertificateVS|0.1.0': '0.1.0/ValueSet-NonIndividualSpecialtyAndDegreeLicenseCertificateVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/NonIndividualSpecialtyAndDegreeLicenseCertificateVS': 'ValueSet-NonIndividualSpecialtyAndDegreeLicenseCertificateVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/OrgTypeVS|0.1.0': '0.1.0/ValueSet-OrgTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/OrgTypeVS': 'ValueSet-OrgTypeVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/PractitionerRolesVS|0.1.0': '0.1.0/ValueSet-PractitionerRolesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/PractitionerRolesVS': 'ValueSet-PractitionerRolesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/QualificationStatusVS|0.1.0': '0.1.0/ValueSet-QualificationStatusVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/QualificationStatusVS': 'ValueSet-QualificationStatusVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/SpecialtiesVS|0.1.0': '0.1.0/ValueSet-SpecialtiesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/SpecialtiesVS': 'ValueSet-SpecialtiesVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/SpecialtyAndDegreeLicenseCertificateVS|0.1.0': '0.1.0/ValueSet-SpecialtyAndDegreeLicenseCertificateVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/ValueSet/SpecialtyAndDegreeLicenseCertificateVS': 'ValueSet-SpecialtyAndDegreeLicenseCertificateVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS|0.1.0': '0.1.0/CodeSystem-AccessibilityCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS': 'CodeSystem-AccessibilityCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/EndpointConnectionTypeCS|0.1.0': '0.1.0/CodeSystem-EndpointConnectionTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/EndpointConnectionTypeCS': 'CodeSystem-EndpointConnectionTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/EndpointPayloadTypeCS|0.1.0': '0.1.0/CodeSystem-EndpointPayloadTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/EndpointPayloadTypeCS': 'CodeSystem-EndpointPayloadTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/HealthcareServiceCategoryCS|0.1.0': '0.1.0/CodeSystem-HealthcareServiceCategoryCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/HealthcareServiceCategoryCS': 'CodeSystem-HealthcareServiceCategoryCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/IndividualPractitionerRoleCS|0.1.0': '0.1.0/CodeSystem-IndividualPractitionerRoleCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/IndividualPractitionerRoleCS': 'CodeSystem-IndividualPractitionerRoleCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/InsurancePlanTypeCS|0.1.0': '0.1.0/CodeSystem-InsurancePlanTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/InsurancePlanTypeCS': 'CodeSystem-InsurancePlanTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/InsuranceProductTypeCS|0.1.0': '0.1.0/CodeSystem-InsuranceProductTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/InsuranceProductTypeCS': 'CodeSystem-InsuranceProductTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/LanguageProficiencyCS|0.1.0': '0.1.0/CodeSystem-LanguageProficiencyCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/LanguageProficiencyCS': 'CodeSystem-LanguageProficiencyCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/NonIndividualPractitionerRoleCS|0.1.0': '0.1.0/CodeSystem-NonIndividualPractitionerRoleCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/NonIndividualPractitionerRoleCS': 'CodeSystem-NonIndividualPractitionerRoleCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/OrgTypeCS|0.1.0': '0.1.0/CodeSystem-OrgTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/OrgTypeCS': 'CodeSystem-OrgTypeCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/QualificationStatusCS|0.1.0': '0.1.0/CodeSystem-QualificationStatusCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/QualificationStatusCS': 'CodeSystem-QualificationStatusCS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CapabilityStatement/plannet-server|0.1.0': '0.1.0/CapabilityStatement-plannet-server.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/CapabilityStatement/plannet-server': 'CapabilityStatement-plannet-server.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/plannet-available-days|0.1.0': '0.1.0/SearchParameter-plannet-available-days.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/plannet-available-days': 'SearchParameter-plannet-available-days.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/plannet-available-end-time|0.1.0': '0.1.0/SearchParameter-plannet-available-end-time.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/plannet-available-end-time': 'SearchParameter-plannet-available-end-time.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/plannet-available-start-time|0.1.0': '0.1.0/SearchParameter-plannet-available-start-time.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/plannet-available-start-time': 'SearchParameter-plannet-available-start-time.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-connection-type|0.1.0': '0.1.0/SearchParameter-endpoint-connection-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-connection-type': 'SearchParameter-endpoint-connection-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-identifier-assigner|0.1.0': '0.1.0/SearchParameter-endpoint-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-identifier-assigner': 'SearchParameter-endpoint-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-identifier|0.1.0': '0.1.0/SearchParameter-endpoint-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-identifier': 'SearchParameter-endpoint-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-mime-type|0.1.0': '0.1.0/SearchParameter-endpoint-mime-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-mime-type': 'SearchParameter-endpoint-mime-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-organization|0.1.0': '0.1.0/SearchParameter-endpoint-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-organization': 'SearchParameter-endpoint-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-payload-type|0.1.0': '0.1.0/SearchParameter-endpoint-payload-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-payload-type': 'SearchParameter-endpoint-payload-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-usecase-standard|0.1.0': '0.1.0/SearchParameter-endpoint-usecase-standard.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-usecase-standard': 'SearchParameter-endpoint-usecase-standard.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-usecase-type|0.1.0': '0.1.0/SearchParameter-endpoint-usecase-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/endpoint-usecase-type': 'SearchParameter-endpoint-usecase-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-characteristic|0.1.0': '0.1.0/SearchParameter-healthcareservice-characteristic.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-characteristic': 'SearchParameter-healthcareservice-characteristic.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-coverage-area|0.1.0': '0.1.0/SearchParameter-healthcareservice-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-coverage-area': 'SearchParameter-healthcareservice-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-endpoint|0.1.0': '0.1.0/SearchParameter-healthcareservice-endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-endpoint': 'SearchParameter-healthcareservice-endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-identifier-assigner|0.1.0': '0.1.0/SearchParameter-healthcareservice-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-identifier-assigner': 'SearchParameter-healthcareservice-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-identifier|0.1.0': '0.1.0/SearchParameter-healthcareservice-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-identifier': 'SearchParameter-healthcareservice-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-location|0.1.0': '0.1.0/SearchParameter-healthcareservice-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-location': 'SearchParameter-healthcareservice-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-name|0.1.0': '0.1.0/SearchParameter-healthcareservice-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-name': 'SearchParameter-healthcareservice-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-new-patient-network|0.1.0': '0.1.0/SearchParameter-healthcareservice-new-patient-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-new-patient-network': 'SearchParameter-healthcareservice-new-patient-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-new-patient|0.1.0': '0.1.0/SearchParameter-healthcareservice-new-patient.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-new-patient': 'SearchParameter-healthcareservice-new-patient.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-organization|0.1.0': '0.1.0/SearchParameter-healthcareservice-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-organization': 'SearchParameter-healthcareservice-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-service-category|0.1.0': '0.1.0/SearchParameter-healthcareservice-service-category.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-service-category': 'SearchParameter-healthcareservice-service-category.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-service-type|0.1.0': '0.1.0/SearchParameter-healthcareservice-service-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-service-type': 'SearchParameter-healthcareservice-service-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-specialty|0.1.0': '0.1.0/SearchParameter-healthcareservice-specialty.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/healthcareservice-specialty': 'SearchParameter-healthcareservice-specialty.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-administered-by|0.1.0': '0.1.0/SearchParameter-insuranceplan-administered-by.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-administered-by': 'SearchParameter-insuranceplan-administered-by.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-area|0.1.0': '0.1.0/SearchParameter-insuranceplan-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-area': 'SearchParameter-insuranceplan-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-benefit-type|0.1.0': '0.1.0/SearchParameter-insuranceplan-coverage-benefit-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-benefit-type': 'SearchParameter-insuranceplan-coverage-benefit-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-network|0.1.0': '0.1.0/SearchParameter-insuranceplan-coverage-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-network': 'SearchParameter-insuranceplan-coverage-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-type|0.1.0': '0.1.0/SearchParameter-insuranceplan-coverage-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-coverage-type': 'SearchParameter-insuranceplan-coverage-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-identifier|0.1.0': '0.1.0/SearchParameter-insuranceplan-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-identifier': 'SearchParameter-insuranceplan-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-name|0.1.0': '0.1.0/SearchParameter-insuranceplan-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-name': 'SearchParameter-insuranceplan-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-network|0.1.0': '0.1.0/SearchParameter-insuranceplan-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-network': 'SearchParameter-insuranceplan-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-owned-by|0.1.0': '0.1.0/SearchParameter-insuranceplan-owned-by.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-owned-by': 'SearchParameter-insuranceplan-owned-by.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-coverage-area|0.1.0': '0.1.0/SearchParameter-insuranceplan-plan-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-coverage-area': 'SearchParameter-insuranceplan-plan-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-identifier|0.1.0': '0.1.0/SearchParameter-insuranceplan-plan-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-identifier': 'SearchParameter-insuranceplan-plan-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-network|0.1.0': '0.1.0/SearchParameter-insuranceplan-plan-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-network': 'SearchParameter-insuranceplan-plan-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-type|0.1.0': '0.1.0/SearchParameter-insuranceplan-plan-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-plan-type': 'SearchParameter-insuranceplan-plan-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-type|0.1.0': '0.1.0/SearchParameter-insuranceplan-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/insuranceplan-type': 'SearchParameter-insuranceplan-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-accessibility|0.1.0': '0.1.0/SearchParameter-location-accessibility.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-accessibility': 'SearchParameter-location-accessibility.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-address|0.1.0': '0.1.0/SearchParameter-location-address.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-address': 'SearchParameter-location-address.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-contains|0.1.0': '0.1.0/SearchParameter-location-contains.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-contains': 'SearchParameter-location-contains.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-identifier-assigner|0.1.0': '0.1.0/SearchParameter-location-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-identifier-assigner': 'SearchParameter-location-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-identifier|0.1.0': '0.1.0/SearchParameter-location-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-identifier': 'SearchParameter-location-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-new-patient-network|0.1.0': '0.1.0/SearchParameter-location-new-patient-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-new-patient-network': 'SearchParameter-location-new-patient-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-new-patient|0.1.0': '0.1.0/SearchParameter-location-new-patient.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-new-patient': 'SearchParameter-location-new-patient.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-organization|0.1.0': '0.1.0/SearchParameter-location-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-organization': 'SearchParameter-location-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-partof|0.1.0': '0.1.0/SearchParameter-location-partof.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-partof': 'SearchParameter-location-partof.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-type|0.1.0': '0.1.0/SearchParameter-location-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/location-type': 'SearchParameter-location-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-city|0.1.0': '0.1.0/SearchParameter-organization-address-city.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-city': 'SearchParameter-organization-address-city.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-country|0.1.0': '0.1.0/SearchParameter-organization-address-country.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-country': 'SearchParameter-organization-address-country.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-postalcode|0.1.0': '0.1.0/SearchParameter-organization-address-postalcode.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-postalcode': 'SearchParameter-organization-address-postalcode.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-state|0.1.0': '0.1.0/SearchParameter-organization-address-state.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address-state': 'SearchParameter-organization-address-state.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address|0.1.0': '0.1.0/SearchParameter-organization-address.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-address': 'SearchParameter-organization-address.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-coverage-area|0.1.0': '0.1.0/SearchParameter-organization-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-coverage-area': 'SearchParameter-organization-coverage-area.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-endpoint|0.1.0': '0.1.0/SearchParameter-organization-endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-endpoint': 'SearchParameter-organization-endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-identifier-assigner|0.1.0': '0.1.0/SearchParameter-organization-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-identifier-assigner': 'SearchParameter-organization-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-identifier|0.1.0': '0.1.0/SearchParameter-organization-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-identifier': 'SearchParameter-organization-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-name|0.1.0': '0.1.0/SearchParameter-organization-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-name': 'SearchParameter-organization-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-partof|0.1.0': '0.1.0/SearchParameter-organization-partof.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-partof': 'SearchParameter-organization-partof.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-code|0.1.0': '0.1.0/SearchParameter-organization-qualification-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-code': 'SearchParameter-organization-qualification-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-issuer|0.1.0': '0.1.0/SearchParameter-organization-qualification-issuer.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-issuer': 'SearchParameter-organization-qualification-issuer.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-wherevalid-code|0.1.0': '0.1.0/SearchParameter-organization-qualification-wherevalid-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-wherevalid-code': 'SearchParameter-organization-qualification-wherevalid-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-wherevalid-location|0.1.0': '0.1.0/SearchParameter-organization-qualification-wherevalid-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-qualification-wherevalid-location': 'SearchParameter-organization-qualification-wherevalid-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-type|0.1.0': '0.1.0/SearchParameter-organization-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organization-type': 'SearchParameter-organization-type.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-identifier-assigner|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-identifier-assigner': 'SearchParameter-organizationaffiliation-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-identifier|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-identifier': 'SearchParameter-organizationaffiliation-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-location|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-location': 'SearchParameter-organizationaffiliation-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-network|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-network': 'SearchParameter-organizationaffiliation-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-participating-organization|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-participating-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-participating-organization': 'SearchParameter-organizationaffiliation-participating-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-primary-organization|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-primary-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-primary-organization': 'SearchParameter-organizationaffiliation-primary-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-role|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-role.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-role': 'SearchParameter-organizationaffiliation-role.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-service|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-service.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-service': 'SearchParameter-organizationaffiliation-service.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-specialty|0.1.0': '0.1.0/SearchParameter-organizationaffiliation-specialty.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/organizationaffiliation-specialty': 'SearchParameter-organizationaffiliation-specialty.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-family-name|0.1.0': '0.1.0/SearchParameter-practitioner-family-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-family-name': 'SearchParameter-practitioner-family-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-given-name|0.1.0': '0.1.0/SearchParameter-practitioner-given-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-given-name': 'SearchParameter-practitioner-given-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-identifier-assigner|0.1.0': '0.1.0/SearchParameter-practitioner-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-identifier-assigner': 'SearchParameter-practitioner-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-identifier|0.1.0': '0.1.0/SearchParameter-practitioner-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-identifier': 'SearchParameter-practitioner-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-name|0.1.0': '0.1.0/SearchParameter-practitioner-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-name': 'SearchParameter-practitioner-name.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-phonetic|0.1.0': '0.1.0/SearchParameter-practitioner-phonetic.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-phonetic': 'SearchParameter-practitioner-phonetic.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-code|0.1.0': '0.1.0/SearchParameter-practitioner-qualification-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-code': 'SearchParameter-practitioner-qualification-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-issuer|0.1.0': '0.1.0/SearchParameter-practitioner-qualification-issuer.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-issuer': 'SearchParameter-practitioner-qualification-issuer.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-wherevalid-code|0.1.0': '0.1.0/SearchParameter-practitioner-qualification-wherevalid-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-wherevalid-code': 'SearchParameter-practitioner-qualification-wherevalid-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-wherevalid-location|0.1.0': '0.1.0/SearchParameter-practitioner-qualification-wherevalid-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitioner-qualification-wherevalid-location': 'SearchParameter-practitioner-qualification-wherevalid-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-endpoint|0.1.0': '0.1.0/SearchParameter-practitionerrole-endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-endpoint': 'SearchParameter-practitionerrole-endpoint.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-identifier-assigner|0.1.0': '0.1.0/SearchParameter-practitionerrole-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-identifier-assigner': 'SearchParameter-practitionerrole-identifier-assigner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-identifier|0.1.0': '0.1.0/SearchParameter-practitionerrole-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-identifier': 'SearchParameter-practitionerrole-identifier.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-location|0.1.0': '0.1.0/SearchParameter-practitionerrole-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-location': 'SearchParameter-practitionerrole-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-network|0.1.0': '0.1.0/SearchParameter-practitionerrole-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-network': 'SearchParameter-practitionerrole-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-new-patient-network|0.1.0': '0.1.0/SearchParameter-practitionerrole-new-patient-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-new-patient-network': 'SearchParameter-practitionerrole-new-patient-network.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-new-patient|0.1.0': '0.1.0/SearchParameter-practitionerrole-new-patient.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-new-patient': 'SearchParameter-practitionerrole-new-patient.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-organization|0.1.0': '0.1.0/SearchParameter-practitionerrole-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-organization': 'SearchParameter-practitionerrole-organization.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-practitioner|0.1.0': '0.1.0/SearchParameter-practitionerrole-practitioner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-practitioner': 'SearchParameter-practitionerrole-practitioner.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-code|0.1.0': '0.1.0/SearchParameter-practitionerrole-qualification-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-code': 'SearchParameter-practitionerrole-qualification-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-issuer|0.1.0': '0.1.0/SearchParameter-practitionerrole-qualification-issuer.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-issuer': 'SearchParameter-practitionerrole-qualification-issuer.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-wherevalid-code|0.1.0': '0.1.0/SearchParameter-practitionerrole-qualification-wherevalid-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-wherevalid-code': 'SearchParameter-practitionerrole-qualification-wherevalid-code.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-wherevalid-location|0.1.0': '0.1.0/SearchParameter-practitionerrole-qualification-wherevalid-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-qualification-wherevalid-location': 'SearchParameter-practitionerrole-qualification-wherevalid-location.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-role|0.1.0': '0.1.0/SearchParameter-practitionerrole-role.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-role': 'SearchParameter-practitionerrole-role.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-service|0.1.0': '0.1.0/SearchParameter-practitionerrole-service.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-service': 'SearchParameter-practitionerrole-service.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-specialty|0.1.0': '0.1.0/SearchParameter-practitionerrole-specialty.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/SearchParameter/practitionerrole-specialty': 'SearchParameter-practitionerrole-specialty.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Endpoint/direct321': 'Endpoint-direct321.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/HealthcareService/cvs-pharmacy': 'HealthcareService-cvs-pharmacy.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/HealthcareService/ffcardiology': 'HealthcareService-ffcardiology.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/HealthcareService/hcs-ws': 'HealthcareService-hcs-ws.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/HealthcareService/independencerehab1': 'HealthcareService-independencerehab1.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/HealthcareService/independencerehab2': 'HealthcareService-independencerehab2.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/InsurancePlan/insuranceplan1': 'InsurancePlan-insuranceplan1.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/cvswindsorct': 'Location-cvswindsorct.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/loc-ffmh-hvi': 'Location-loc-ffmh-hvi.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/loc-ffmh': 'Location-loc-ffmh.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/loc-ws': 'Location-loc-ws.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/wash-dc-metro': 'Location-wash-dc-metro.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/patriotppo': 'Organization-patriotppo.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/CVS': 'Organization-CVS.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/foundingfathers': 'Organization-foundingfathers.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/homeland': 'Organization-homeland.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/independencerehab': 'Organization-independencerehab.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/monumentHIE': 'Organization-monumentHIE.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/mtvernon': 'Organization-mtvernon.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/patriotdental': 'Organization-patriotdental.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/OrganizationAffiliation/orgrole1': 'OrganizationAffiliation-orgrole1.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/OrganizationAffiliation/orgrole2': 'OrganizationAffiliation-orgrole2.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Practitioner/practitioner1': 'Practitioner-practitioner1.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/PractitionerRole/practitionerrole1': 'PractitionerRole-practitionerrole1.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/location1WSAddress': 'Location-location1WSAddress.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/HealthcareService/nutrition-healthcareservice-1238863986': 'HealthcareService-nutrition-healthcareservice-1238863986.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/InsurancePlan/plannet-insuranceplan-HPID400000': 'InsurancePlan-plannet-insuranceplan-HPID400000.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/plannet-location-1230085657': 'Location-plannet-location-1230085657.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/plannet-location-1230188327': 'Location-plannet-location-1230188327.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Location/plannet-location-PCY-0002302': 'Location-plannet-location-PCY-0002302.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/plannet-network-HPID040000': 'Organization-plannet-network-HPID040000.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Endpoint/plannet-organization-1230085657-direct': 'Endpoint-plannet-organization-1230085657-direct.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/plannet-organization-1230085657': 'Organization-plannet-organization-1230085657.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/plannet-organization-1239774646': 'Organization-plannet-organization-1239774646.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Organization/plannet-organization-3b4358447f58795888ada0a39': 'Organization-plannet-organization-3b4358447f58795888ada0a39.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/Practitioner/plannet-practitioner-1232506780': 'Practitioner-plannet-practitioner-1232506780.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/PractitionerRole/plannet-practitionerrole-1232506780': 'PractitionerRole-plannet-practitionerrole-1232506780.html',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/PractitionerRole/plannet-practitionerrole-1236743399': 'PractitionerRole-plannet-practitionerrole-1236743399.html'}

# %% [markdown]
# #### Then Use Jinja2 template to create narrative

# %%
in_path = ''
in_file = 'R4capabilitystatement-server.j2'

def markdown(text, *args, **kwargs):
    return commonmark(text, *args, **kwargs)



env = Environment(
    loader=FileSystemLoader(searchpath = in_path),
    autoescape=select_autoescape(['html','xml','xhtml','j2','md'])
    )

env.filters['markdown'] = markdown


template = env.get_template(in_file)

sp_map = {sp.code:sp.type for sp in df_sp.itertuples(index=True)}
pname_map = {p.Profile:p.Name for p in df_profiles.itertuples(index=True)}
pprint(pname_map)

rendered = template.render(cs=cs, path_map=path_map, pname_map = pname_map, sp_map =sp_map )

display(HTML(rendered))


parser = etree.XMLParser(remove_blank_text=True)
root = etree.fromstring(rendered, parser=parser)

div = (etree.tostring(root[1][0], encoding='unicode', method='html'))
narr = N.Narrative()
narr.status = 'generated'
narr.div = div
cs.text = narr


#print(dumps(cs.as_json(),indent=3))
# Out:
# {'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Endpoint': 'Plan-Net '
#                                                                                       'Endpoint',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-HealthcareService': 'Plan-Net '
#                                                                                                'HealthcareService',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-InsurancePlan': 'Plan-Net '
#                                                                                            'InsurancePlan',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location': 'Plan-Net '
#                                                                                       'Location',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Network': 'Plan-Net '
#                                                                                      'Network',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Organization': 'Plan-Net '
#                                                                                           'Organization',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-OrganizationAffiliation': 'Plan-Net '
#                                                                                                      'OrganizationAffiliation',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Practitioner': 'Plan-Net '
#                                                                                           'Practitioner',
#  'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-PractitionerRole': 'Plan-Net '
#                                                                                               'PractitionerRole'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-4c61258fc803> in <module>
#      21 pprint(pname_map)
#      22
# ---> 23 rendered = template.render(cs=cs, path_map=path_map, pname_map = pname_map, sp_map =sp_map )
#      24
#      25 display(HTML(rendered))
#
# /Library/Python/3.7/site-packages/jinja2/environment.py in render(self, *args, **kwargs)
#    1088             return concat(self.root_render_func(self.new_context(vars)))
#    1089         except Exception:
# -> 1090             self.environment.handle_exception()
#    1091
#    1092     def render_async(self, *args, **kwargs):
#
# /Library/Python/3.7/site-packages/jinja2/environment.py in handle_exception(self, source)
#     830         from .debug import rewrite_traceback_stack
#     831
# --> 832         reraise(*rewrite_traceback_stack(source=source))
#     833
#     834     def join_path(self, template, parent):
#
# /Library/Python/3.7/site-packages/jinja2/_compat.py in reraise(tp, value, tb)
#      26     def reraise(tp, value, tb=None):
#      27         if value.__traceback__ is not tb:
# ---> 28             raise value.with_traceback(tb)
#      29         raise value
#      30
#
# ~/git/MyNotebooks/CapStatement/R4capabilitystatement-server.j2 in top-level template code()
#     108 {% endif %}
#     109
# --> 110                         {% for r in cs.rest[0].resource %}
#     111                         <h4 class="no_toc" id="{{r.type | lower }}">{{r.type}}</h4>
#     112
#
# /Library/Python/3.7/site-packages/jinja2/runtime.py in __init__(self, iterable, undefined, recurse, depth0)
#     401         """
#     402         self._iterable = iterable
# --> 403         self._iterator = self._to_iterator(iterable)
#     404         self._undefined = undefined
#     405         self._recurse = recurse
#
# /Library/Python/3.7/site-packages/jinja2/runtime.py in _to_iterator(iterable)
#     409     @staticmethod
#     410     def _to_iterator(iterable):
# --> 411         return iter(iterable)
#     412
#     413     @property
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ### validate again

# %%
print('...validating')
r = validate(cs)
display(HTML(f'<h1>Validation output</h1><h3>Status Code = {r.status_code}</h3> {r.json()["text"]["div"]}'))
# Out:
# ...validating
# <h1>Validation output</h1><h3>Status Code = 500</h3> <div xmlns="http://www.w3.org/1999/xhtml"><p>No Database Connections Available for "Operation" (used: InUse 100 of 100: Operation 5 days (Select Ids.ResourceKey, Types.ResourceName, Ids.Id, VersionId, Secure, StatedDate, Name, Versions.Status, Score1, Score2, Tags, JsonContent from Versions, Ids, Sessions, SearchEntries, Types where Ids.Deleted = 0 and SearchEntries.ResourceVersionKey = Versions.ResourceVersionKey and Types.ResourceTypeKey = Ids.ResourceTypeKey and Versions.SessionKey = Sessions.SessionKey and SearchEntries.ResourceKey = Ids.ResourceKey and SearchEntries.SearchKey = 24235 order by SortValue ASC)
# fhir.sweep 5 days (insert into Versions (ResourceVersionKey, ResourceKey, StatedDate, TransactionDate, VersionId, Format, Status, SessionKey, ForTesting, Secure, Tags, XmlContent, XmlSummary, JsonContent, JsonSummary) values (:k, :rk, :sd, :td, :v, :f, 0, :s, :ft, :sec, :tb, :xc, :xs, :jc, :js))
# Indexing Lookup 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (Insert into SearchEntries Select 24236, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (Insert into SearchEntries Select 24237, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (Insert into SearchEntries Select 24238, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (Insert into SearchEntries Select 24239, ResourceKey, MostRecent as ResourceVersionKey, Id, null, null from Ids where Deleted = 0 and MostRecent is not null and Ids.MasterResourceKey is null order by ResourceKey DESC)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Provenance')
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Provenance')
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Patient')
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select ResourceTypeKey from Types where supported = 1 and ResourceName = 'Provenance')
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supported = 1 and ResourceName = :n)
# Operation 5 days (select Ids.ResourceKey, Ids.MostRecent, Deleted from Ids, Types where Ids.id = :s  and Ids.ResourceTypeKey = Types.ResourceTypeKey and Supp

# %% [markdown]
# ### Write to folder

# %%
# save to file
print('...........saving to file............')
#save in ig_source folder
path = Path.cwd() / ig_source_path / 'resources' / f'capabilitystatement-{cs.id.lower()}.json'
path.write_text(dumps(cs.as_json(), indent=4))
# Out:
# ...........saving to file............
# 4287
